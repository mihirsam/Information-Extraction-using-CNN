# %%
from CNN import tCNN

# %% [markdown]
# ## Getting Data

# %%
import pickle
with open('Data_souravGaungly.pkl', 'rb') as f:
    Final = pickle.load(f)
    
X = Final[0]
Y = Final[1]

# %% [markdown]
# ## Random Shuffle

# %%
import random

XY = list(zip(X, Y))
random.shuffle(XY)

X, Y = zip(*XY)

# %%
len(X)
# Out:
# 274

# %%
tCNN()


from keras.utils import plot_model
from IPython.display import Image
from keras.models import load_model

model = load_model('CNN_model_init.h5')
plot_model(model, to_file='CNN_arch.png')
Image(filename='./CNN_arch.png')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %% [markdown]
# ## Reshaping Array

# %%
import numpy as np

X = np.asarray(X)
Y = np.asarray(Y)

X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
Y = Y.reshape(Y.shape[0], 1)

print(f"X shape : {X.shape}\nY shape : {Y.shape}")
# Out:
# X shape : (274, 10, 10, 1)
# Y shape : (274, 1)

# %%
x_train = X[0:200]
y_train = Y[0:200]

x_test = X[200:]
y_test = Y[200:]

# %% [markdown]
# ## Training Model

# %%
# callback function
import keras
import matplotlib.pyplot as plt

class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc')>0.90):
            print("\nReached 90% accuracy so cancelling training!")
            self.model.stop_training = True
        
callback = myCallback()

history = model.fit(x_train, y_train,
          epochs=1000,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=[callback])

try:
    model.save('CNN_model_sauravGaungly.h5')
    print("Model Saved!")
except:
    print("Error in saving Model")
# Out:
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 200 samples, validate on 74 samples
# Epoch 1/1000
# 200/200 [==============================] - 1s 7ms/step - loss: 5.2093 - acc: 0.1400 - val_loss: 5.0807 - val_acc: 0.1351
# Epoch 2/1000
# 200/200 [==============================] - 0s 972us/step - loss: 3.9427 - acc: 0.1700 - val_loss: 3.0887 - val_acc: 0.2568
# Epoch 3/1000
# 200/200 [==============================] - 0s 1ms/step - loss: 2.7682 - acc: 0.2500 - val_loss: 2.7719 - val_acc: 0.2838
# Epoch 4/1000
# 200/200 [==============================] - 0s 981us/step - loss: 2.0507 - acc: 0.3400 - val_loss: 2.1585 - val_acc: 0.3378
# Epoch 5/1000
# ...

# %% [markdown]
# ## Plotting Model Accuracy and Loss

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model_accuracy_sauravGaungly.png', bbox_inches='tight')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model_loss_sauravGaungly.png', bbox_inches='tight')

# %%
score = model.evaluate(x_test, y_test, verbose=0)
score
# Out:
# [0.6155344231708629, 0.8378378346159652]
