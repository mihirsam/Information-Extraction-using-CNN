# %%
from CNN import tCNN

# %% [markdown]
# ### Getting Data

# %%
import pickle
with open('Data_worldwar2.pkl', 'rb') as f:
    Final = pickle.load(f)
    
X = Final[0]
Y = Final[1]

# %% [markdown]
# ### Random Shuffle

# %%
import random

XY = list(zip(X, Y))
random.shuffle(XY)

X, Y = zip(*XY)

# %%
tCNN()


from keras.utils import plot_model
from IPython.display import Image
from keras.models import load_model

model = load_model('CNN_model_init.h5')
plot_model(model, to_file='CNN_arch.png')
Image(filename='./CNN_arch.png')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %% [markdown]
# ## Reshaping array

# %%
import numpy as np

X = np.asarray(X)
Y = np.asarray(Y)

X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
Y = Y.reshape(Y.shape[0], 1)

print(f"X shape : {X.shape}\nY shape : {Y.shape}")
# Out:
# X shape : (169, 10, 10, 1)
# Y shape : (169, 1)

# %%
x_train = X[0:140]
y_train = Y[0:140]

x_test = X[140:]
y_test = Y[140:]

# %% [markdown]
# ### Training Model

# %%
# callback function
import keras
import matplotlib.pyplot as plt

class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc')>0.90):
            print("\nReached 90% accuracy so cancelling training!")
            self.model.stop_training = True
        
callback = myCallback()

history = model.fit(x_train, y_train,
          epochs=1000,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=[callback])

try:
    model.save('CNN_model_worldwar2.h5')
    print("Model Saved!")
except:
    print("Error in saving Model")
# Out:
# WARNING:tensorflow:From C:\Users\Xenon\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 140 samples, validate on 29 samples
# Epoch 1/1000
# 140/140 [==============================] - 4s 26ms/step - loss: 1.9948 - acc: 0.1643 - val_loss: 1.7357 - val_acc: 0.3448
# Epoch 2/1000
# 140/140 [==============================] - 0s 1ms/step - loss: 1.5832 - acc: 0.5214 - val_loss: 1.4435 - val_acc: 0.7586
# Epoch 3/1000
# 140/140 [==============================] - 0s 1ms/step - loss: 1.2993 - acc: 0.8571 - val_loss: 1.2286 - val_acc: 0.8276
# Epoch 4/1000
# 140/140 [==============================] - 0s 920us/step - loss: 1.0738 - acc: 0.9357 - val_loss: 1.0325 - val_acc: 0.9310
#
# Reached 90% accuracy so cancelling training!
# ...

# %% [markdown]
# ## Plotting Model Accuracy and Loss

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model_accuracy_worldwar2.png', bbox_inches='tight')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Model_loss_worldwar2.png', bbox_inches='tight')

# %%
score = model.evaluate(x_test, y_test, verbose=0)
score
# Out:
# [1.2166534662246704, 0.8965517282485962]

# %%
classes = model.predict(x_test)
print(classes)
# Out:
# [[1.66687340e-01 8.55415761e-02 1.44482832e-02 3.55084538e-01
#   5.95456548e-02 1.59705102e-01 8.58507529e-02 7.31367320e-02]
#  [2.05612838e-01 9.94629487e-02 2.33658291e-02 1.49478063e-01
#   9.08258930e-02 1.38332680e-01 1.56005457e-01 1.36916369e-01]
#  [9.54417288e-02 1.13488592e-01 1.72668770e-02 1.71613738e-01
#   8.28873813e-02 3.10880125e-01 8.85425881e-02 1.19878896e-01]
#  [3.49467546e-01 1.37010768e-01 1.37404287e-02 1.76963344e-01
#   5.45190684e-02 1.12393811e-01 8.10525268e-02 7.48524442e-02]
#  [1.14804655e-01 5.77532411e-01 4.17320011e-03 7.90878907e-02
#   3.38891149e-02 9.67834517e-02 5.81154712e-02 3.56137529e-02]
#  [1.55865997e-01 1.04832016e-01 9.59590171e-03 1.48614973e-01
#   5.31921312e-02 3.50038797e-01 7.58784637e-02 1.01981774e-01]
#  [3.28320682e-01 1.27571195e-01 1.96281858e-02 1.42171949e-01
#   7.49296397e-02 9.95130837e-02 1.07355997e-01 1.00509197e-01]
#  [1.53955624e-01 1.02858298e-01 1.76490322e-02 1.88201606e-01
# ...

# %%
classes.shape
# Out:
# (29, 8)

# %%
x_test.shape
# Out:
# (29, 10, 10, 1)

# %%
y_test[0]
# Out:
# array([3])
